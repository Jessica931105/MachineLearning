# %%
# !pip install Flask pyngrok line-bot-sdk requests --quiet
# !pip install google-genai --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.5/819.5 kB 15.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 11.2 MB/s eta 0:00:00

# %%
from google.colab import userdata

ngrok_authtoken = userdata.get('NGROK_AUTHTOKEN')
line_channel_access_token = userdata.get('LINE_CHANNEL_ACCESS_TOKEN')
line_channel_secret = userdata.get('LINE_CHANNEL_SECRET')
gemini_api_key = userdata.get('GEMINI_API_KEY')
port = 5051

# %%
import os
from pyngrok import ngrok

# %%
ngrok.kill()

# %%
import requests

ngrok.set_auth_token(ngrok_authtoken)
tunnel = ngrok.connect(5051, name="linebot_tunnel")
webhook_url = tunnel.public_url

print(f"Ngrok URL: {webhook_url}")

# 自動更新 LINE Webhook URL
def update_line_webhook(webhook_url):
    """使用 LINE Messaging API 更新 Webhook URL"""
    url = "https://api.line.me/v2/bot/channel/webhook/endpoint"
    headers = {
        "Authorization": f"Bearer {line_channel_access_token}",
        "Content-Type": "application/json"
    }
    data = {
        "endpoint": webhook_url
    }

    response = requests.put(url, headers=headers, json=data)

    if response.status_code == 200:
        print(f"✅ LINE Webhook URL 已自動更新為：{webhook_url}")
        return True
    else:
        print(f"❌ 更新失敗：{response.status_code} - {response.text}")
        return False

# 執行更新
update_line_webhook(webhook_url)
# Out:
# Ngrok URL: https://exterior-everyone-gander.ngrok-free.dev
# ✅ LINE Webhook URL 已自動更新為：https://exterior-everyone-gander.ngrok-free.dev
# True

# %%
from google import genai

client = genai.Client(api_key=gemini_api_key)

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="什麼是AI AGENT？"
)
print(response.text)
# Out:
# **AI Agent (AI 智能體)** 是一種能夠感知環境、進行思考決策、並採取行動以達成特定目標的智能實體。你可以將它想像成一個有著「大腦」（AI 模型，通常是大型語言模型 LLM）和「手腳」（工具接口）的數位助理或任務執行者。
#
# 它不僅能理解你的指令，還能自主地規劃步驟、執行複雜的任務，並根據環境變化進行調整。
#
# ### 核心概念與運作原理：
#
# AI Agent 的運作可以用一個循環來概括：
#
# 1.  **感知 (Perception)：**
#     *   Agent 透過各種方式（如文本輸入、API 數據、文件內容、圖像、語音等）從其環境中獲取信息。
#     *   它「看」到或「聽到」了什麼。
#
# 2.  **思考/決策 (Thinking/Decision-making)：**
#     *   Agent 使用其內置的 AI 模型（例如 LLM）來處理感知到的信息。
#     *   它會分析問題、理解目標、檢索相關知識、規劃執行步驟、甚至預測行動後果。
#     *   這個階段可能涉及任務分解、邏輯推理、記憶檢索等。
#     *   它「想」怎麼做才能達成目標。
#
# 3.  **行動 (Action)：**
#     *   根據決策，Agent 執行一系列行動來影響其環境。
#     *   這些行動可以是：
#         *   生成文本（回覆問題、寫報告、編寫代碼）。
#         *   呼叫外部工具或 API（發送郵件、查詢數據庫、運行程序、瀏覽網頁）。
#         *   物理操作（如果是機器人 Agent）。
#     *   它「做」了什麼。
#
# 4.  **環境反饋 (Environment Feedback)：**
#     *   Agent 的行動會導致環境發生變化。Agent 再次感知這些變化，形成一個新的循環。
#     *   透過這種方式，Agent 可以評估其行動是否成功，並在必要時調整策略。
#     *   它「看」到行動的結果如何。
#
# ### AI Agent 的關鍵組成部分：
#
# 一個典型的 AI Agent 通常包含以下核心模組：
#
# 1.  **核心 AI 模型 (Core AI Model)：** 這是 Agent 的「大腦」，通常是一個大型語言模型（LLM），負責理解、推理、規劃和生成響應。
# 2.  **記憶 (Memory)：**
#     *   **短期記憶 (Short-term Memory)：** 用於當前對話或任務的上下文信息。
#     *   **長期記憶 (Long-term Memory)：** 儲存知識庫、學習到的經驗、用戶偏好等，讓 Agent 能從過往互動中學習。
# 3.  **規劃模組 (Planning Module)：** 負責將複雜的目標分解為可執行的子任務，並制定完成這些子任務的策略。
# 4.  **工具使用模組 (Tool-Use/Action Module)：** 讓 Agent 能夠調用外部工具、API 或程式碼來執行超越其自身語言模型能力的任務（例如上網搜索、計算、操作文件、執行程式碼）。
# 5.  **感知模組 (Perception Module)：** 負責從環境中收集信息並將其轉換為 AI 模型可以理解的格式。
#
# ### 為什麼 AI Agent 很重要？
#
# AI Agent 的興起代表著 AI 應用從簡單的「響應式」對話（你問我答）向更複雜、更「自主式」的任務執行轉變：
#
# *   **自主性：** 能夠在最少的人工干預下自主完成多步驟、複雜的任務。
# *   **效率提升：** 自動化繁瑣和重複性工作，極大地提高生產力。
# *   **多功能性：** 透過整合多種工具，Agent 可以處理各種不同類型的任務。
# *   **個性化與適應性：** 能夠學習用戶偏好和環境變化，提供更個性化的服務。
# *   **解決複雜問題：** 能夠將複雜問題分解並逐步解決。
#
# ### 應用實例：
#
# *   **智能助理：** 不僅回答問題，還能預定機票、管理日程、發送郵件等。
# *   **自動化編程助手：** 根據需求自動編寫、測試、調試程式碼，甚至部署應用。
# *   **研究與信息檢索 Agent：** 自動搜索、篩選和總結互聯網上的信息，生成報告。
# *   **個人化學習 Agent：** 根據學習者的進度調整課程內容、提供練習和反饋。
# *   **智能家居管理：** 自動控制家居設備，根據用戶習慣和環境變化調整設置。
# *   **金融交易 Agent：** 監測市場數據，自主執行交易策略。
#
# 總之，AI Agent 正在將人工智能從單純的語言處理器轉變為一個真正的智能工作夥伴，能夠理解、規劃並執行更廣泛、更深入的任務。

# %%
def stateless_query(payload):
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=payload
    )
    return response.text

# %%
result = stateless_query("簡介明新科技大學")
print(result)
# Out:
# 明新科技大學（Ming Hsin University of Science and Technology, MHUST）是一所位於**臺灣新竹縣新豐鄉**的知名私立科技大學。
#
# 以下是其簡要介紹：
#
# 1.  **創校歷史與沿革**：
#     *   創立於**1966年**，最初名為「明新工程專科學校」。
#     *   歷經多次改制與升格，於2002年正式改制為「明新科技大學」。
#     *   學校歷史悠久，擁有豐富的教學經驗和辦學傳統。
#
# 2.  **辦學理念與特色**：
#     *   秉持「**理論與實務並重，學術與應用結合**」的理念。
#     *   強調「**務實致用**」和「**產業鏈結**」，致力於培養具備專業技能、實作能力和創新思維的產業人才。
#     *   與周邊的**新竹科學園區**及其他產業聚落合作密切，提供學生豐富的實習和就業機會。
#
# 3.  **學院設置**：
#     *   目前設有多個學院，主要包括：
#         *   **工程學院**
#         *   **管理學院**
#         *   **服務產業學院**
#         *   **通識教育中心**
#     *   提供學士、碩士等多層次的學位課程，涵蓋工程、管理、設計、服務等多元領域。
#
# 4.  **校園環境與資源**：
#     *   校園環境優美，設有現代化的教學大樓、實驗室、圖書館、體育設施及學生宿舍等。
#     *   積極引進產學合作資源，建置許多符合產業需求的實作場域與設備，提升學生的實務操作能力。
#
# 5.  **社會聲譽與成就**：
#     *   畢業生因其紮實的專業技能和良好的職業素養，在業界具有良好的口碑和競爭力。
#     *   多次獲得教育部獎勵，並在各項評鑑中表現優異，顯示其在技職教育領域的卓越貢獻。
#
# 總結來說，明新科技大學是一所強調實用技能、緊密結合產業的綜合型科技大學，致力於為社會培育各行各業所需的高素質專業人才。

# %%
from flask import Flask, request, abort

from linebot.v3 import (
    WebhookHandler
)
from linebot.v3.exceptions import (
    InvalidSignatureError
)
from linebot.v3.messaging import (
    Configuration,
    ApiClient,
    MessagingApi,
    ReplyMessageRequest,
    TextMessage,
)
from linebot.v3.webhooks import (
    MessageEvent,
    TextMessageContent,
)

app = Flask(__name__)

configuration = Configuration(access_token=line_channel_access_token)
handler = WebhookHandler(line_channel_secret)


@app.route("/", methods=['POST'])
def callback():
    # get X-Line-Signature header value
    signature = request.headers['X-Line-Signature']

    # get request body as text
    body = request.get_data(as_text=True)
    print("BODY: ", body)
    app.logger.info("Request body: " + body)

    # handle webhook body
    try:
        handler.handle(body, signature)
    except InvalidSignatureError:
        app.logger.info("Invalid signature. Please check your channel access token/channel secret.")
        abort(400)

    return 'OK'


@handler.add(MessageEvent, message=TextMessageContent)
def handle_message(event):
    text = event.message.text
    with ApiClient(configuration) as api_client:
        line_bot_api = MessagingApi(api_client)
        if text.startswith('AI '):#這邊有限定AI 開頭的才會用gemini
            prompt = text[3:]
            reply_text = stateless_query(prompt)
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=reply_text)]
                )
            )

        else:
            line_bot_api.reply_message_with_http_info(
                ReplyMessageRequest(
                    reply_token=event.reply_token,
                    messages=[TextMessage(text=event.message.text),
                        TextMessage(text=event.message.text)]
                )
            )

if __name__ == "__main__":
    app.run(port=port)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5051
# INFO:werkzeug:Press CTRL+C to quit
# BODY:  {"destination":"U4bf2ca05145c0285eed4eb00c147e436","events":[{"type":"message","message":{"type":"text","id":"615030928632185249","quoteToken":"n-rTJ3DiMevuXawzMWVLroV4airnZpd92j2f1CSCoRudqFGPLmdsUG2jax549vOQpH6ryHK5EkO9p0ODKD4az7uDXpTtoDEZb0W5WepIRePKGoqy1gQUYYQKItjziEiQFTSWUbHaUZycXvbU5WgWdQ","markAsReadToken":"heP03m5QyOOEvbxIbbETCmUSh3GfhCKozkzADx--Kepogx3HBs8NKBN2wn6Q_-0tQdweH-lfElzjojuc0Oko_IAf30TtDW7Mw_CKzyAh2QeYTGJjCTAANzoFJIazKmJMzH1BFGPIRj7LOcsuqNJhWXEfCyrXsDtVGJyWPxvzK8RQkFWuKRPDU5dbeBd95y7vOfokyI-CGqrX91XWICLsvg","text":"AI 簡介明新科大"},"webhookEventId":"01KS6SH45XF93PKFR209CPA2Y9","deliveryContext":{"isRedelivery":false},"timestamp":1779418304372,"source":{"type":"user","userId":"U7de6d64df43af01c22a89a5ae823b57a"},"replyToken":"311e4491669d487a806e05e49e6f6c40","mode":"active"}]}
# INFO:werkzeug:127.0.0.1 - - [22/May/2026 02:51:55] "POST / HTTP/1.1" 200 -
